# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Salary_data_Cleaned.csv')

# %%
df.head()
# Out:
#                    Job Title Salary Estimate  \
# 0             Data Scientist           53-91
# 1  Healthcare Data Scientist          63-112
# 2             Data Scientist           80-90
# 3             Data Scientist           56-97
# 4             Data Scientist          86-143
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# ...

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age      python         sql  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   50.322102    0.528302    0.512129
# ...

# %% [markdown]
# ## Data Distribution of Numerical Columns

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.age.hist()
# Out:
# <Axes: >

# %%
df.desc_length.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column=['age','avg_salary'])
# Out:
# <Axes: >

# %%
df.boxplot(column='Rating')
# Out:
# <Axes: >

# %%
df.boxplot(column=['desc_length'])
# Out:
# <Axes: >

# %% [markdown]
# ### Checking Correlation between variables

# %%
df[['desc_length','Rating','age','avg_salary']].corr()
# Out:
#              desc_length    Rating       age  avg_salary
# desc_length     1.000000 -0.012281  0.164995    0.078808
# Rating         -0.012281  1.000000  0.027660    0.013492
# age             0.164995  0.027660  1.000000    0.019328
# avg_salary      0.078808  0.013492  0.019328    1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['desc_length','Rating','age','avg_salary','num_comp']].corr(), cmap=cmap, vmax=.3,center=0)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'job_state', 'same_state', 'age', 'python', 'sql', 'excel', 'tableau',
#        'desc_length', 'job_simplified', 'seniority', 'num_comp'],
#       dtype='object')

# %% [markdown]
# ## Data Distribution of Categorical Columns

# %%
df_categorical=df[['Company Name','Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','job_state', 'same_state','python', 'sql', 'excel', 'tableau',
        'job_simplified', 'seniority']]

# %%
columns_to_exclude = ['Company Name', 'Location', 'Headquarters','Industry']
columns_to_plot = [col for col in df_categorical.columns if col not in columns_to_exclude]

for i in columns_to_plot:
    categorical_num = df_categorical[i].value_counts()
    chart = sns.barplot(x=categorical_num.index, y=categorical_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.xlabel(i)
    plt.show()
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\2312972943.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\2312972943.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\2312972943.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\2312972943.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
for i in df_categorical[['Company Name','Location', 'Headquarters','Industry']].columns:
    categorical_num=df_categorical[i].value_counts()[:20]
    chart=sns.barplot(x=categorical_num.index,y=categorical_num)
    chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
    plt.show()
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\1706738992.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\1706738992.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\1706738992.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_16604\1706738992.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'job_state', 'same_state', 'age', 'python', 'sql', 'excel', 'tableau',
#        'desc_length', 'job_simplified', 'seniority', 'num_comp'],
#       dtype='object')

# %% [markdown]
# ## Comparing Salary in different Scenarios

# %%
pd.pivot_table(df,index=['job_simplified','seniority'],values='avg_salary')
# Out:
#                           avg_salary
# job_simplified seniority
# analyst        junior      56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist junior     106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows',None)

# %%
pd.pivot_table(df,index=['job_state','job_simplified'],values='avg_salary',aggfunc='count').sort_values('job_state',ascending=False)
# Out:
#                           avg_salary
# job_state job_simplified
# wi        na                       4
#           data scientist           3
#           analyst                  3
# wa        na                       1
#           data scientist          17
#           analyst                  3
# va        na                       5
#           mle                      2
#           data scientist          18
#           data engineer           10
#           analyst                  6
# ut        data engineer            3
#           analyst                  4
#           data scientist           3
# tx        na                       7
#           data scientist          13
#           data engineer            8
# tn        data scientist           1
#           data engineer           10
#           analyst                  2
# sc        na                       1
# ri        analyst                  1
# pa        manager                  3
# ...

# %%
pd.pivot_table(df[df['job_simplified']=='data scientist'],index='job_state',values='avg_salary').sort_values('avg_salary',ascending=False)
# Out:
#            avg_salary
# job_state
# dc         149.000000
# ca         142.522059
# ut         140.500000
# mo         127.666667
# il         117.233333
# nc         117.000000
# ny         115.250000
# ma         113.750000
# wi         113.500000
# pa         113.333333
# md         109.115385
# co         108.666667
# va         108.416667
# nj         106.875000
# mi         106.625000
# oh         105.285714
# tx         100.730769
# wa          99.764706
# or          98.500000
# fl          97.357143
# tn          96.000000
# in          84.500000
# ky          84.000000
# ct          84.000000
# ga          81.333333
# nm          74.333333
# az          69.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'job_state', 'same_state', 'age', 'python', 'sql', 'excel', 'tableau',
#        'desc_length', 'job_simplified', 'seniority', 'num_comp'],
#       dtype='object')

# %%
# Some more scerarios are
# rating,type of ownership,industry,sector,revenue,no of comp,hourly,employer provided,python,sql,excel,tableau,desc_len

# %%
df_pivots=df[['Rating','Type of ownership','Industry','Sector','Revenue','num_comp','hourly','employer_provided','python','sql','excel','tableau','desc_length','avg_salary']]

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows',None)

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index=i, values='avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Type of ownership
#                                 avg_salary
# Type of ownership
# -1                              117.500000
# Company - Public                110.893782
# Subsidiary or Business Segment  110.573529
# College / University            107.615385
# Company - Private               101.776829
# ...

# %%
pd.pivot_table(df_pivots,index="Revenue",columns='python',values='avg_salary',aggfunc='count')
# Out:
# python                               0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %% [markdown]
# # Creating a Word Cloud

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhruv\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
